# %%
#matrix operations
m=[
    [1,2,3],
    [4,5,6],
    [7,8,9],
]
a=[]
b=[]
c=[]
d=[]
for i in range(0,1):
    a.append((m[0][0],m[1][0],m[2][0]))
    a.append((m[0][1],m[1][1],m[2][1]))
    a.append((m[0][2],m[1][2],m[2][2]))
    d.append((m[0][0]+m[1][0]+m[2][0]))
    d.append((m[0][1]+m[1][1]+m[2][1]))
    d.append((m[0][2]+m[1][2]+m[2][2]))
print(a)
print(d)

for i in range(0,1):
    b.append((m[0][0]+m[0][1]+m[0][2]))
    b.append((m[1][0]+m[1][1]+m[1][2]))
    b.append((m[2][0]+m[2][1]+m[2][2]))
    c.append((m[0][0]+m[1][1]+m[2][2]))
print(b)
print(c)
# Out:
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]
# [12, 15, 18]
# [6, 15, 24]
# [15]

# %%
def is_balanced(s):
    stack=[]
    pairs={')':'(',']':'[','}':'{'}
    for ch in s:
        if ch in '([{':
            return True
        elif ch in ')]}':
            return False
    return True
tests=["(())","([{}])","(()","([)]",""]
for t in tests:
    print(t,is_balanced(t))
# Out:
# (()) True
# ([{}]) True
# (() True
# ([)] True
#  True

# %%
def compress(s):
    if not s:
        return ""
    result=" "
    return result
for word in["aabcccddd","abcd","aaabba","aaaaaa"]:
    print(word,{compress(word)})
# Out:
# aabcccddd {' '}
# abcd {' '}
# aaabba {' '}
# aaaaaa {' '}

# %%
def __init__(self,color):
    self.color=color
def area(self):
    return 0
def describe(self):
    return f"{self.color} {self.__class__.__name} with area {self.area():2f}"
class Rectangle(shape):
    def __init__(self,color,width,height):
        pass
    def area(self):
        return width * height
class Triangle(shape):
    def __init__(self,color,base,height):
        pass
    def area(self):
        return 0.5 * base * height
shapes=[
    circle("red",7),
    rectangle("blue",5,8),
    Triangle("green",6,10),
]
for s in shapes:
    print(s.describe())
print("largest:",max(shapes,key=lambda s:s.area()).describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-5fea36fd2f23> in <module>
#       5 def describe(self):
#       6     return f"{self.color} {self.__class__.__name} with area {self.area():2f}"
# ----> 7 class Rectangle(shape):
#       8     def __init__(self,color,width,height):
#       9         pass
#
# NameError: name 'shape' is not defined
